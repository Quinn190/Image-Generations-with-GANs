# %%
import tensorflow as tf

import glob
import imageio
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
import cv2

from IPython import display

# %%
PATH = "images"

IMG_SIZE = 256

# %%
labels = os.listdir(path)

# %%
def getimages(path):
    data = []
    for label in labels:
        imagelocation = os.path.join(path, label)
        class_num = labels.index(label)
        for img in os.listdir(imagelocation):
            img = PIL.Image.open(imagelocation + '/' + img)
            resized_img = img.resize((IMG_SIZE,IMG_SIZE))
        
        data.append([resized_img, class_num])
        
    return data

# %%
images = getimages(PATH)

# %%
image.size
# Out:
# (1280, 720)

# %%
def getminmaximagesize(paths):
    minx = 1000
    maxx = 0
    miny = 1000
    maxy = 0
    for i in paths:
        image = PIL.Image.open(path + "/" + i)
        
        minx = min(minx, image.size[0])
        maxx = max(maxx, image.size[0])
        miny = min(miny, image.size[1])
        maxy = max(maxy, image.size[1])
        
    return minx, maxx, miny, maxy

# %%
x, y, z, a = getminmaximagesize(images)

# %%
imagedataset[9]
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2511C61ED08>

# %%
imagedataset = []
for img in os.listdir(path):
    im = PIL.Image.open(path + "/" + img)
    im = im.resize((128, 128))
    imagedataset.append(im)

# %% [raw]
# imagedataset

# %%
x = image.resize((64,64,))

# %%
images
# Out:
# ['00de09e7e9ca7221a12ff0394b993705.jpg',
#  '01d5d233d2b688b680c2e6323af9661c.jpg',
#  '03122e1aa1e6b6c879313d058669bc71.jpg',
#  '04c357fce035d2c96089901596a210d2.jpg',
#  '056aeb476d97eda97eef09b06e7074c0.jpg',
#  '0f0962c180985f49cf78b3247902fac8.jpg',
#  '0f410c7d09f7dca70577db70dfe90e6f.jpg',
#  '10c2ce2d910afe025bfaf0207fe0a2eb.jpg',
#  '19b8477c5b58e770663e6db4608b912b.jpg',
#  '1a99a8748099425a99e478ab1ff99456.jpg',
#  '1fd8ab0f16f82be59e3c0c1d9cdfab7f.jpg',
#  '2204859a28ded6a2892ce1186b1c41b3.jpg',
#  '221466561c8a752d01a9e1b709b1833f.jpg',
#  '26cb2f20b806924570c9c5835fb39c1f.jpg',
#  '277198231eaea293e9bd9be991ed17f9.jpg',
#  '3143bc4238726b9a1d71b188f7fcfcaf.jpg',
#  '38f5c8b6ce44373fe088d51649911492.jpg',
#  '395cac00345947a1a6f01b3b87c21ad2.jpg',
#  '396b8c78bc0b2c3dfb6eb9118f2ae21e.jpg',
#  '3dcdff1ec0e97dac4b50432499dd9f25.jpg',
#  '40ddde63dbfb0a707544cc4dba810f79.jpg',
#  '47eee886d9c9d5f1bda51991465382b9.jpg',
#  '4836a2f1ff8e5dc8c9a15a2ab214d7bb.jpg',
# ...
